# %%
import requests
import json
import pandas as pd
import numpy as np
import yaml
import nltk

# Get the API key from a yaml file

with open("api_key.yaml", "r") as f:
    config = yaml.safe_load(f)
API_KEY = config["API_KEY"]

# Get the data from the API

url = f"https://api.themoviedb.org/3/discover/movie?api_key={API_KEY}&sort_by=popularity.desc"
response = requests.get(url)

# %%
data = response.json()

# %%
def generator_review(movie_id):
    reviews = []
    for page in range(1, 6):
        url_reviews = f"https://api.themoviedb.org/3/movie/{movie_id}/reviews?api_key={API_KEY}&page={page}"
        response_reviews = requests.get(url_reviews)
        data_reviews = response_reviews.json()
        for review in data_reviews["results"]:
            reviews.append(review["content"])
    return reviews

# %%
nltk.tokenize.sent_tokenize("Hi here")
# Out:
# ['Hi here']

# %%
all_sentences = []
for review in generator_review(502356):
    for sentence in nltk.tokenize.sent_tokenize(review.replace(' -', ' .').replace(',', '.').replace(':', '.')):
        all_sentences.append(sentence)

# %%
from nltk.sentiment import SentimentIntensityAnalyzer, vader

sia = SentimentIntensityAnalyzer()
sia.polarity_scores("I love this movie")
print(sia.polarity_scores("But the film is massively unfunny."))

via = vader.SentimentIntensityAnalyzer()
via.polarity_scores("I love this movie")
print(via.polarity_scores("But the film is massively unfunny."))
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
import transformers

classifier = transformers.pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading config.json: 100%|██████████| 629/629 [00:00<00:00, 210kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 255M/255M [00:09<00:00, 29.1MB/s]
# Downloading tokenizer_config.json: 100%|██████████| 48.0/48.0 [00:00<00:00, 24.0kB/s]
# Downloading vocab.txt: 100%|██████████| 226k/226k [00:00<00:00, 2.72MB/s]

# %%
def positivity_score(sentence):
    sign = 1 if classifier(sentence)[0]["label"] == "POSITIVE" else -1
    return classifier(sentence)[0]["score"] * sign

sentence_scores = [(sentence, positivity_score(sentence)) for sentence in all_sentences]

# %%
sentence_scores.sort(key=lambda x: x[1], reverse=True)

# %%
ordered_reviews = pd.DataFrame(sentence_scores, columns=["sentence", "score"])

# %%
sia.polarity_scores("I love this movie")
# Out:
# {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.6369}

# %%
def model(sentence):
    return sia.polarity_scores(sentence)["compound"]

reviews = generator_review(502356)

explainer = shap.Explainer(model)
shap_values = explainer(reviews)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Projets\nextMovie\scripts\understand_api.ipynb Cell 12 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Projets/nextMovie/scripts/understand_api.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> reviews = generator_review(502356)
#       <a href='vscode-notebook-cell:/c%3A/Projets/nextMovie/scripts/understand_api.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> explainer = shap.Explainer(model)
# ----> <a href='vscode-notebook-cell:/c%3A/Projets/nextMovie/scripts/understand_api.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> shap_values = explainer(reviews)
#
# File c:\Users\Wassim\Python\Python39\lib\site-packages\shap\explainers\_permutation.py:82, in Permutation.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args)
#      78 def __call__(self, *args, max_evals=500, main_effects=False, error_bounds=False, batch_size="auto",
#      79              outputs=None, silent=False):
#      80     """ Explain the output of the model on the given arguments.
#      81     """
# ---> 82     return super().__call__(
#      83         *args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds, batch_size=batch_size,
#      84         outputs=outputs, silent=silent
#      85     )
#
# File c:\Users\Wassim\Python\Python39\lib\site-packages\shap\explainers\_explainer.py:266, in Explainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     264     feature_names = [[] for _ in range(len(args))]
#     265 for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__+" explainer", silent):
# --> 266     row_result = self.explain_row(
#     267         *row_args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
#     268         batch_size=batch_size, outputs=outputs, silent=silent, **kwargs
#     269     )
#     270     values.append(row_result.get("values", None))
#     271     output_indices.append(row_result.get("output_indices", None))
#
# File c:\Users\Wassim\Python\Python39\lib\site-packages\shap\explainers\_permutation.py:92, in Permutation.explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *row_args)
#      88 """ Explains a single row and returns the tuple (row_values, row_expected_values, row_mask_shapes).
#      89 """
#      91 # build a masked version of the model for the current input sample
# ---> 92 fm = MaskedModel(self.model, self.masker, self.link, self.linearize_link, *row_args)
#      94 # by default we run 10 permutations forward and backward
#      95 if max_evals == "auto":
#
# File c:\Users\Wassim\Python\Python39\lib\site-packages\shap\utils\_masked_model.py:48, in MaskedModel.__init__(self, model, masker, link, linearize_link, *args)
#      46 else:
#      47     self._masker_rows = None# # just assuming...
# ---> 48     self._masker_cols = sum(np.prod(a.shape) for a in self.args)
#      50 self._linearizing_weights = None
#
# File c:\Users\Wassim\Python\Python39\lib\site-packages\shap\utils\_masked_model.py:48, in <genexpr>(.0)
#      46 else:
#      47     self._masker_rows = None# # just assuming...
# ---> 48     self._masker_cols = sum(np.prod(a.shape) for a in self.args)
#      50 self._linearizing_weights = None
#
# AttributeError: 'str' object has no attribute 'shape'

# %%
all_sentences
# Out:
# ['_The Super Mario Bros. Movie_ is like Fruit Stripe Gum.',
#  'It’s super colorful and eyecatching.',
#  'but it seems to instantly lose its flavor and charm.',
#  'The film is visually stunning and Jack Black is outstanding as Bowser.',
#  'The big action sequences are like big budget versions of the Mario video games playthroughs with little welcome surprises thrown in.',
#  'But the film is massively unfunny.',
#  'the characters are extremely flat.',
#  'and the flimsy writing is about as complex as an unkempt mustache.',
#  '**Full review.',
#  '** https.//boundingintocomics.com/2023/04/06/the-super-mario-bros-movie-review-plunging-rainbow-colored-nostalgia-to-death/',
#  "I am not the demographic and to be honest this isn't really a film that I was ever going to like either.",
#  'The story is beyond simple and the game-based animation .',
#  'though expertly crafted .',
#  'did absolutely nothing for me as ninety minutes rolled along devoid of characterisations.',
#  'thrill or much sense of adventure.',
#  'I got the feeling this was really an outing for "Mario".',
#  '"Luigi" and "Peach" designed to satisfy the die-hard fans.',
#  'or the children .',
#  'or both.',
#  'but if you were not in on the game from the start then you are unlikely to have become any more engaged by the end of this fungi-fest.',
#  "It wouldn't be fair to say this is bland .",
#  "it's not designed to challenge or take risks.",
#  'it\'s fun for those who grew up with "Mario" et al in their lives and I\'m not going to decry that.',
#  "It's colourful.",
#  'pacy.',
#  'and at times quite well written but perhaps it ought to have a rating that says if you are over 12 then you should be advised against it?']

# %%
nltk.sent_tokenize(text)

# %%
# Create a dataframe from the data

df = pd.DataFrame(data['results'])

# %%
df
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /9n2tJBplPbgR2ca05hS5CKXwP2c.jpg  [16, 12, 10751, 14, 35]   502356
# 1   False  /5i6SjyDbDWqyun8klUuCxrlFbyw.jpg                 [18, 28]   677179
# 2   False  /ovM06PdF3M8wvKb06i4sjW3xoww.jpg            [878, 12, 28]    76600
# 3   False  /bT3IpP7OopgiVuy6HCPOWLuaFAd.jpg           [35, 9648, 28]   638974
# 4   False  /wybmSmviUXxlBmX44gtpow5Y9TB.jpg             [28, 35, 14]   594767
# 5   False  /vSUls0b7dNhC7tJoExF1MBYWWyh.jpg  [16, 35, 10751, 12, 14]   816904
# 6   False  /i8dshLvq4LE3s0v8PrkDdUyb1ae.jpg             [28, 53, 80]   603692
# 7   False  /a2tys4sD7xzVaogPntGsT1ypVoT.jpg             [53, 35, 80]   804150
# 8   False  /5Y5pz0NX7SZS9036I733F7uNcwK.jpg               [27, 9648]   758323
# 9   False  /ouB7hwclG7QI3INoYJHaZL4vOaa.jpg  [16, 10751, 14, 12, 35]   315162
# 10  False  /eNJhWy7xFzR74SYaSJHqJZuroDm.jpg                [28, 878]  1033219
# 11  False  /u5nY7pY2Y58o7dSM9cy6NclOV8V.jpg                     [27]  1023313
# 12  False  /wD2kUCX1Bb6oeIb2uz7kbdfLP6k.jpg                 [27, 53]   980078
# 13  False  /sgFDQwJTYMuUS7Ng4PAPB8nBf2j.jpg    [28, 18, 27, 878, 53]  1084225
# 14  False  /m1fgGSLK0WvRpzM1AmZu38m0Tx8.jpg                     [28]   842945
# 15  False                              None                     [53]  1076605
# 16  False  /eSVu1FvGPy86TDo4hQbpuHx55DJ.jpg        [878, 12, 53, 28]   700391
# 17  False  /xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg            [28, 12, 878]   505642
# 18  False  /2Eewgp7o5AU1xCataDmiIL2nYxd.jpg                 [18, 36]   943822
# 19  False  /4840rkbpsiuow5ew155oVKcqJwj.jpg                     [18]      615
#
#    original_language                         original_title  \
# 0                 en            The Super Mario Bros. Movie
# 1                 en                              Creed III
# 2                 en               Avatar: The Way of Water
# 3                 en                       Murder Mystery 2
# 4                 en               Shazam! Fury of the Gods
# 5                 es                                 Momias
# 6                 en                   John Wick: Chapter 4
# 7                 en                           Cocaine Bear
# 8                 en                    The Pope's Exorcist
# 9                 en           Puss in Boots: The Last Wish
# 10                en                        Attack on Titan
# 11                es                           La Exorcista
# 12                en       Winnie the Pooh: Blood and Honey
# 13                en                               The Park
# 14                en                              Supercell
# 15                es                               Cazadora
# 16                en                                     65
# 17                en         Black Panther: Wakanda Forever
# 18                en  Prizefighter: The Life of Jem Belcher
# 19                en              The Passion of the Christ
#
#                                              overview  popularity  \
# 0   While working underground to fix a water main,...    9065.306
# 1   After dominating the boxing world, Adonis Cree...    5253.149
# 2   Set more than a decade after the events of the...    4810.649
# 3   After starting their own detective agency, Nic...    3571.437
# 4   Billy Batson and his foster siblings, who tran...    5827.392
# 5   Through a series of unfortunate events, three ...    1725.865
# 6   With the price on his head ever increasing, Jo...    1840.121
# 7   Inspired by a true story, an oddball group of ...    1550.773
# 8   Father Gabriele Amorth, Chief Exorcist of the ...    1768.271
# 9   Puss in Boots discovers that his passion for a...    1878.108
# 10  As viable water is depleted on Earth, a missio...    1100.962
# 11  Ophelia, a young nun recently arriving in the ...     950.408
# 12  Christopher Robin is headed off to college and...    1187.936
# 13  A dystopian coming-of-age movie focused on thr...    1080.758
# 14  Good-hearted teenager William always lived in ...    1447.479
# 15  In a dystopian future, a mother and her teenag...     870.025
# 16  65 million years ago, the only 2 survivors of ...    1918.606
# 17  Queen Ramonda, Shuri, M’Baku, Okoye and the Do...     956.696
# 18  At the turn of the 19th century, Pugilism was ...     837.948
# 19  A graphic portrayal of the last twelve hours o...     366.007
#
#                          poster_path release_date  \
# 0   /qNBAXBIQlnOThrVvA6mA2B5ggV6.jpg   2023-04-05
# 1   /cvsXj3I9Q2iyyIo95AecSd1tad7.jpg   2023-03-01
# 2   /t6HIqrRAclMCA60NsSmeqe9RmNV.jpg   2022-12-14
# 3   /wdffZv8gIiWy6xr4t7hWBWtUwpl.jpg   2023-03-28
# 4   /A3ZbZsmsvNGdprRi2lKgGEeVLEH.jpg   2023-03-15
# 5    /qVdrYN8qu7xUtsdEFeGiIVIaYd.jpg   2023-01-05
# 6    /vZloFAK7NmvMGKE7VkF5UHaz0I.jpg   2023-03-22
# 7   /gOnmaxHo0412UVr1QM5Nekv1xPi.jpg   2023-02-22
# 8   /9JBEPLTPSm0d1mbEcLxULjJq9Eh.jpg   2023-04-05
# 9   /kuf6dutpsT0vSVehic3EZIqkOBt.jpg   2022-12-07
# 10  /ay8SLFTMKzQ0i5ewOaGHz2bVuZL.jpg   2022-09-30
# 11  /d07xtqwq1uriQ1hda6qeu8Skt5m.jpg   2022-11-02
# 12   /fNTtVbqI92abEKAgz2ynurCUne.jpg   2023-01-27
# 13  /hR1jdCw0A9czgsbp45TASkjjBhA.jpg   2023-03-02
# 14  /gbGHezV6yrhua0KfAgwrknSOiIY.jpg   2023-03-17
# 15   /8QxCd3pSSrj6QqaG4fkNkaJmUa.jpg   2023-01-19
# 16  /rzRb63TldOKdKydCvWJM8B6EkPM.jpg   2023-03-02
# 17  /sv1xJUazXeYqALzczSZ3O6nkH75.jpg   2022-11-09
# 18  /x3PIk93PTbxT88ohfeb26L1VpZw.jpg   2022-06-30
# 19  /2C9vyK6leWDb2ds65R7uIwSmh8V.jpg   2004-02-25
#
#                                     title  video  vote_average  vote_count
# 0             The Super Mario Bros. Movie  False           7.5         631
# 1                               Creed III  False           7.3         924
# 2                Avatar: The Way of Water  False           7.7        6947
# 3                        Murder Mystery 2  False           6.5         616
# 4                Shazam! Fury of the Gods  False           7.0         723
# 5                                 Mummies  False           7.1         143
# 6                    John Wick: Chapter 4  False           8.0         971
# 7                            Cocaine Bear  False           6.5         729
# 8                     The Pope's Exorcist  False           7.1          38
# 9            Puss in Boots: The Last Wish  False           8.3        5144
# 10                        Attack on Titan  False           6.1          48
# 11                           The Exorcist  False           5.5          59
# 12       Winnie the Pooh: Blood and Honey  False           5.8         415
# 13                               The Park  False           5.6          27
# 14                              Supercell  False           6.2          73
# 15                               Cazadora  False           5.9          15
# 16                                     65  False           6.3         424
# 17         Black Panther: Wakanda Forever  False           7.3        4498
# 18  Prizefighter: The Life of Jem Belcher  False           6.2         114
# 19              The Passion of the Christ  False           7.5        3845
